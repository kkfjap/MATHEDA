# %% [markdown]
# # LIST AND TUPLES <hr style="border:2.5px solid #38c0e9ff">
# </hr>

# %% [markdown]
# <b> Kyla Faith A. Pedrajas </b>
# <br> Computer Engineer

# %% [markdown]
# # Creating a List

# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ["apple", "banana", "cherry", "mango"]
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
mixed_list = [1, "hello", 3.14, True, [2, 4, 6]]
mixed_list
# Out:
# [1, 'hello', 3.14, True, [2, 4, 6]]

# %% [markdown]
# # Indexing

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
numbers[-1]
# Out:
# 5

# %% [markdown]
# # Modifying

# %%
fruits = ["apple", "banana", "cherry", "mango"]
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
"apple" in fruits
# Out:
# True

# %%
fruits[0] = "orange"

# %%
fruits
# Out:
# ['orange', 'banana', 'cherry', 'mango']

# %%
"apple" in fruits
# Out:
# False

# %% [markdown]
# # Adding Elements

# %%
fruits = ["apple", "banana", "cherry", "mango"]
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango']

# %%
fruits.append("orange")
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'orange']

# %%
fruits.insert(1, "blueberry")

# %% [markdown]
# # Removing Elements

# %%
"banana" in fruits
# Out:
# True

# %%
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'cherry', 'mango', 'orange']

# %%
fruits.remove("banana")

# %%
fruits
# Out:
# ['apple', 'blueberry', 'cherry', 'mango', 'orange']

# %%
"banana" in fruits
# Out:
# False

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['blueberry', 'cherry', 'mango', 'orange']

# %% [markdown]
# # Sort(0) and Sorted()

# %%
numbers = [3,4,5,6,1,2]
numbers
# Out:
# [3, 4, 5, 6, 1, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
sorted(numbers, reverse=True)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
numbers
# Out:
# [3, 4, 5, 6, 1, 2]

# %%
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
sorted(numbers, reverse = True)
# Out:
# [6, 5, 4, 3, 2, 1]

# %% [markdown]
# # Slicing

# %%
chars = ['a', 'b', 'c', 'd', 'x', 'y', 'z']
chars
# Out:
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %%
len(chars)
# Out:
# 7

# %%
sub = chars[1:4]

# %%
sub
# Out:
# ['b', 'c', 'd']

# %%
chars
# Out:
# ['a', 'b', 'c', 'd', 'x', 'y', 'z']

# %%
chars[0:7:2]
# Out:
# ['a', 'c', 'x', 'z']

# %% [markdown]
# # TUPLES

# %%
my_tuple = (1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[0:6:2]
# Out:
# (1, 3, 5)

# %%
my_tuple = (2, 2, 3, 4, 5)
my_tuple
# Out:
# (2, 2, 3, 4, 5)

# %%
my_tuple = (10, "hola", 3.14, False)
my_tuple
# Out:
# (10, 'hola', 3.14, False)
