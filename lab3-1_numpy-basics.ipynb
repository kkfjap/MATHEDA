# %% [markdown]
# <h1 style="text-align:center; border:2.5px solid rgb(72, 208, 242)"> # Numpy Basics </h1>

# %% [markdown]
# <b>Kyla Faith A. Pedrajas</b>
# <br> Computer Engineer

# %%
# %pip install numpy --upgrade
# %pip install scipy --upgrade
# Out:
# Requirement already satisfied: numpy in c:\users\hp\desktop\cpe - 2a\2nd term\matheda\.venv\lib\site-packages (2.4.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\hp\desktop\cpe - 2a\2nd term\matheda\.venv\lib\site-packages (1.17.0)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\users\hp\desktop\cpe - 2a\2nd term\matheda\.venv\lib\site-packages (from scipy) (2.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\hp\desktop\cpe - 2a\2nd term\matheda\.venv\lib\site-packages (25.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# imports and packages
import numpy as np
from scipy import stats
from statistics import multimode

# %% [markdown]
# # 1D Array

# %%
# 1-dimensional array
array_a = np.array([1, 2, 3])
array_a
# Out:
# array([1, 2, 3])

# %%
#size of an array
np.shape(array_a)
# Out:
# (3,)

# %%
#1 dimensional aray
array_b = np.array([[4, 5, 6]])
array_b
# Out:
# array([[4, 5, 6]])

# %% [markdown]
# # 2D Array

# %%
# 2 dimensional array
my_array = np.array([[1, 2, 3], 
                    [4, 5, 6]])
my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#size of matrix
np.shape(my_array)
# Out:
# (2, 3)

# %%
#transpose of  a matrix
t_array = my_array.T
t_array
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
#size of matrix
np.shape(t_array)
# Out:
# (3, 2)

# %% [markdown]
# # Measures of Central Tendency

# %%
#Jaguar vs Panther
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8 ],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
np.shape(resistance)
# Out:
# (2, 11)

# %%
resistance.T
# Out:
# array([[10.6, 10.1],
#        [ 9.1, 11. ],
#        [ 9.3,  9.1],
#        [ 9.8, 20. ],
#        [10.5,  9.2],
#        [10.4, 10.8],
#        [ 9.5,  9.9],
#        [11. ,  9.2],
#        [10.4,  9.1],
#        [ 3. ,  9.1],
#        [ 9.8,  nan]])

# %%
np.mean(resistance, axis=0)
# Out:
# array([10.35, 10.05,  9.2 , 14.9 ,  9.85, 10.6 ,  9.7 , 10.1 ,  9.75,
#         6.05,   nan])

# %%
np.mean(resistance, axis=1)
# Out:
# array([9.4, nan])

# %%
#mean
np.nanmean(resistance, axis=1)
# Out:
# array([ 9.4 , 10.75])

# %%
jag_mean = np.nanmean(resistance, axis=1)[0]
pan_mean = np.nanmean(resistance, axis=1)[1]

print(f'Jaguar_mean = {jag_mean: .2f} ohms')
print(f'Panther_mean = {pan_mean: .2f} ohms')
# Out:
# Jaguar_mean =  9.40 ohms
# Panther_mean =  10.75 ohms

# %%
# Median
np.nanmedian(resistance, axis=1)
# Out:
# array([9.8 , 9.55])

# %%
jag_median = np.nanmedian(resistance, axis=1)[0]
pan_median = np.nanmedian(resistance, axis=1)[1]

print(f'Jaguar_median = {jag_median: .2f} ohms')
print(f'Panther_median = {pan_median: .2f} ohms')
# Out:
# Jaguar_median =  9.80 ohms
# Panther_median =  9.55 ohms

# %%
#Mode
stats.mode(resistance, axis=1)
# Out:
# ModeResult(mode=array([9.8, 9.1]), count=array([2, 3]))

# %%
my_array = [1,1,2,2,3,4,5]
multimode (my_array)
# Out:
# [1, 2]

# %%
jag_res = resistance[0]
print("Jaguar mode: ")
for i in multimode(jag_res):
    print(f'{i} ohms')
# Out:
# Jaguar mode:
# 9.8 ohms
# 10.4 ohms

# %%
pan_res = resistance[1]
print("Panther mode: ")    
for i in multimode(pan_res):
    print(f'{i} ohms')
# Out:
# Panther mode:
# 9.1 ohms

# %% [markdown]
# # Measures of Variability

# %%
# Jaguar vs Panther
resistance = np.array([
    [10.6, 9.1, 9.3, 9.8, 10.5, 10.4, 9.5, 11, 10.4, 3, 9.8 ],
    [10.1, 11, 9.1, 20, 9.2, 10.8, 9.9, 9.2, 9.1, 9.1, np.nan]
])
resistance
# Out:
# array([[10.6,  9.1,  9.3,  9.8, 10.5, 10.4,  9.5, 11. , 10.4,  3. ,  9.8],
#        [10.1, 11. ,  9.1, 20. ,  9.2, 10.8,  9.9,  9.2,  9.1,  9.1,  nan]])

# %%
# Range
res_max = np.nanmax(resistance, axis=1)
res_min = np.nanmin(resistance, axis=1)
res_range = res_max - res_min
res_range
# Out:
# array([ 8. , 10.9])

# %%
print(f'jaguar range = {res_range[0]: .2f} ohms')
print(f'panther range = {res_range[1]: .2f} ohms')
# Out:
# jaguar range =  8.00 ohms
# panther range =  10.90 ohms

# %%
#1st Quartile
res_Q1 = np.nanpercentile(resistance, 25, axis=1)
res_Q1
# Out:
# array([9.4  , 9.125])

# %%
#2nd Quartile
res_Q2 = np.nanpercentile(resistance, 50, axis=1)
res_Q2
# Out:
# array([9.8 , 9.55])

# %%
# 3rd Quartile
res_Q3 = np.nanpercentile(resistance, 75, axis=1)
res_Q3
# Out:
# array([10.45 , 10.625])

# %%
#IQR
print(f'Jaguar IQR = {res_Q3[0] - res_Q1[0]: .2f} ohms')
print(f'Panther IQR = {res_Q3[1] - res_Q1[1]: .2f} ohms')
# Out:
# Jaguar IQR =  1.05 ohms
# Panther IQR =  1.50 ohms

# %%
#Variance
res_var = np.nanvar(resistance, ddof=1, axis=1)
res_var
# Out:
# array([ 4.86      , 11.08277778])

# %%
print(f'Jaguar Variance = {res_var[0]: .2f} ohms')
print(f'Panther Variance = {res_var[1]: .2f} ohms')
# Out:
# Jaguar Variance =  4.86 ohms
# Panther Variance =  11.08 ohms

# %%
#Standard Deviation
res_std = np.nanstd(resistance, ddof=1, axis=1)
res_std
# Out:
# array([2.20454077, 3.32908062])

# %%
print(f'Jaguar Standard Deviation = {res_std[0]: .2f} ohms')
print(f'Panther Standard Deviation = {res_std[1]: .2f} ohms')
# Out:
# Jaguar Standard Deviation =  2.20 ohms
# Panther Standard Deviation =  3.33 ohms
