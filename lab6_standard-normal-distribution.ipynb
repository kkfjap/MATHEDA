# %% [markdown]
# <h1 style="text-align:center; border:2.5px solid rgb(72, 208, 242)">  Standard Normal Distribution </h1>

# %% [markdown]
# <b> Kyla Faith A. Pedrajas </b>
# <br> Computer Engineer

# %%
# %pip install pandas numpy matplotlib scipy
# Out:
# Requirement already satisfied: pandas in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (2.4.1)
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: scipy in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\hp\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# imports and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd. DataFrame([1, 2, 2, 3, 3, 3, 4, 4, 5],
                   columns=['dataset'])
df
# Out:
#    dataset
# 0        1
# 1        2
# 2        2
# 3        3
# 4        3
# 5        3
# 6        4
# 7        4
# 8        5

# %%
df.describe()
# Out:
#         dataset
# count  9.000000
# mean   3.000000
# std    1.224745
# min    1.000000
# 25%    2.000000
# 50%    3.000000
# 75%    4.000000
# max    5.000000

# %%
#Z-
df['z_score'] = stats.zscore(df['dataset'], ddof=1)
df
# Out:
#    dataset   z_score
# 0        1 -1.632993
# 1        2 -0.816497
# 2        2 -0.816497
# 3        3  0.000000
# 4        3  0.000000
# 5        3  0.000000
# 6        4  0.816497
# 7        4  0.816497
# 8        5  1.632993

# %%
#Load Dataset
df = pd.read_csv(r"dataset\current-test.csv",
                delimiter=",")
df
# Out:
#     Sample  Current
# 0        1     12.0
# 1        2     15.0
# 2        3      8.3
# 3        4      9.7
# 4        5     12.0
# 5        6     13.9
# 6        7     14.1
# 7        8      9.2
# 8        9     12.4
# 9       10     13.7
# 10      11     10.6
# 11      12     21.5
# 12      13     12.0
# 13      14      9.3
# 14      15     11.2
# 15      16      3.3
# 16      17     12.4
# 17      18     12.3
# 18      19     13.8
# 19      20     10.5
# 20      21     10.4
# 21      22     15.0
# 22      23     12.7
# 23      24     14.4
# 24      25     11.0
# 25      26      9.1
# 26      27     10.2
# 27      28     12.4
# 28      29      7.0
# 29      30     14.8

# %%
df['Current'][2]
# Out:
# np.float64(8.3)

# %%
#Load Dataset
df = pd.read_csv(r"dataset\current-test.csv",
                delimiter=",",
                index_col='Sample')
df
# Out:
#         Current
# Sample
# 1          12.0
# 2          15.0
# 3           8.3
# 4           9.7
# 5          12.0
# 6          13.9
# 7          14.1
# 8           9.2
# 9          12.4
# 10         13.7
# 11         10.6
# 12         21.5
# 13         12.0
# 14          9.3
# 15         11.2
# 16          3.3
# 17         12.4
# 18         12.3
# 19         13.8
# 20         10.5
# 21         10.4
# 22         15.0
# 23         12.7
# 24         14.4
# 25         11.0
# 26          9.1
# 27         10.2
# 28         12.4
# 29          7.0
# 30         14.8

# %%
df['Current'][4:6]
# Out:
# Sample
# 5    12.0
# 6    13.9
# Name: Current, dtype: float64

# %%
sample_1 = df['Current'][3:5].mean()
sample_1
# Out:
# np.float64(10.85)

# %%
#Summary of Statistics
df.describe()
# Out:
#          Current
# count  30.000000
# mean   11.806667
# std     3.166629
# min     3.300000
# 25%    10.250000
# 50%    12.000000
# 75%    13.775000
# max    21.500000

# %%
#Z-score
df['Z-score'] = stats.zscore(df['Current'], ddof=1)
df
# Out:
#         Current   Z-score
# Sample
# 1          12.0  0.061053
# 2          15.0  1.008433
# 3           8.3 -1.107382
# 4           9.7 -0.665271
# 5          12.0  0.061053
# 6          13.9  0.661060
# 7          14.1  0.724219
# 8           9.2 -0.823168
# 9          12.4  0.187371
# 10         13.7  0.597902
# 11         10.6 -0.381057
# 12         21.5  3.061089
# 13         12.0  0.061053
# 14          9.3 -0.791588
# 15         11.2 -0.191581
# 16          3.3 -2.686348
# 17         12.4  0.187371
# 18         12.3  0.155791
# 19         13.8  0.629481
# 20         10.5 -0.412636
# 21         10.4 -0.444216
# 22         15.0  1.008433
# 23         12.7  0.282109
# 24         14.4  0.818957
# 25         11.0 -0.254740
# 26          9.1 -0.854747
# 27         10.2 -0.507374
# 28         12.4  0.187371
# 29          7.0 -1.517913
# 30         14.8  0.945274

# %%
df['Z-score'].describe()
# Out:
# count    3.000000e+01
# mean     7.401487e-18
# std      1.000000e+00
# min     -2.686348e+00
# 25%     -4.915848e-01
# 50%      6.105335e-02
# 75%      6.215863e-01
# max      3.061089e+00
# Name: Z-score, dtype: float64

# %% [markdown]
# # Histogram

# %%
#Histogram Plot
plt.hist(df['Current'], bins=5, 
         alpha = 0.8,
         color= 'cyan',
         edgecolor = 'black')
plt.show()

# %%
#Histogram Plot
plt.hist(df['Current'], bins=5, 
         alpha = 0.8,
         color = "#AB1212",
         edgecolor = "#000000")

plt.title('Histogram of Current Values',
          font = 'Arial', 
          fontsize=14)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency') 
plt.show()

# %% [markdown]
# # Normal Distribution

# %%
#normal distribution curve
mean = df['Current'].mean()
std = df['Current'].std(ddof=1)

#x-axis
x_min = df['Current'].min() 
x_max = df['Current'].max()

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.plot(x, p,
         color = "#2E04E9",
         linewidth = 2)

plt.title('Normal Distribution Curve of Current Values',
          font = 'Palatino Linotype', 
          fontsize=14)
plt.xlabel('Current (mA)')
plt.ylabel('Probability Density')   
plt.show()

# %%
#normal distribution curve
mean = df['Current'].mean()
std = df['Current'].std(ddof=1)

#x-axis
x_min = df['Current'].min() 
x_max = df['Current'].max()

#Histogram Plot
plt.hist(df['Current'], bins=5, 
         density =  True,
         alpha = 0.8,
         color = "#750606",
         edgecolor = "#000000")

plt.title('Histogram of Current Values',
          font = 'Palatino Linotype', 
          fontsize=14)
plt.xlabel('Current (mA)')
plt.ylabel('Frequency') 

x = np.linspace(x_min, x_max, 100)
p = stats.norm.pdf(x, mean, std)

plt.plot(x, p,
         color = "#404DFF",
         linewidth = 2)

plt.xlabel('Current (mA)')
plt.ylabel('Probability Density')   
plt.show()

# %%
#Standard Normal DIstribution N(0, 1)
#x-axis
x_max = df['Z-score'].max()
x_min = df['Z-score'].min()
x= np.linspace(x_min, x_max, 100)

p = stats.norm.pdf(x, df['Z-score'].mean(), df['Z-score'].std(ddof=1))

plt.plot(x, p,
         color = "#FF5733",
         linewidth = 3)
plt.title('Standard Normal DIstribution N(0, 1)',
          font = 'Palatino Linotype', 
          fontsize=14)  
plt.xlabel('Z-score')
plt.ylabel('Probability Density')
plt.show()
